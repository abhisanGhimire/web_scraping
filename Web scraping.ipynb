# %%
import requests

product_ids=['prod1840201', 'prod21231906', 'P03014583', 'prod20151218', '156274', 'prod14430038', 'P03000424', 'P03004900', '156271', 'prod1250255', 'prod1250212', 'prod450460', 'prod11691392', 'P03002219', 'prod25940193', 'P03013400', 'P03015957', 'P03014874', 'prod23650079', 'prod1840201', 'prod21231906', 'P03014583', 'prod20151218', '156274', 'prod14430038', 'P03000424', 'P03004900', '156271', 'prod1250255', 'prod1250212', 'prod450460', 'prod11691392', 'P03002219', 'prod25940193', 'P03013400', 'P03015957', 'P03014874', 'prod23650079']
product_ids=set(product_ids)
product_ids=list(product_ids)


cookies = {
    'SSLB': '1',
    'sxp-rl-SAT_OD_SURVEY-rn': '44',
    'sxp-rl-SAT_GEO_LOC-rn': '69',
    'sxp-rl-SAT_OPA_CART-rn': '64',
    'sxp-rl-SAT_CHAT-rn': '72',
    'sxp-rl-SAT_CART_SUBSTITUTIONS-rn': '64',
    'SCR_PICR': '0',
    'az-reg': 'scus',
    'TS0171ed6c': '01538efd7cb3cae2bbdc6593e911d9e38be307f87498b7fa04bd2bece136ff4fddf10764da858c6563e8a93e49cfc04f8a1c4a23b5',
    'sxp-rl-SAT_DISABLE_SYN_PREQUALIFY-rn': '4',
    'vtc': 'c1iSjC5gAV2WXfRUHiKcbI',
    'sxp-rl-SAT_REORDER_V3-rn': '67',
    'sxp-rl-SCR_SHAPEJS-rn': '62',
    'TS01b2183e': '01538efd7cb3cae2bbdc6593e911d9e38be307f87498b7fa04bd2bece136ff4fddf10764da858c6563e8a93e49cfc04f8a1c4a23b5',
    'SAT_WPWCNP': '1',
    'sxp-rl-SAT_CHAT-c': 'r|1|100',
    'SCR_SHAPEJS': '0',
    'sxp-rl-SCR_SHAPEJS-c': 'r|1|0',
    'SAT_REORDER_V3': '0',
    'sxp-rl-SAT_OD_SURVEY-c': 'r|1|20',
    'SAT_DISABLE_SYN_PREQUALIFY': '0',
    'sxp-rl-SAT_OPA_CART-c': 'r|3|20',
    'sxp-rl-SAT_DISABLE_SYN_PREQUALIFY-c': 'r|1|0',
    'SAT_GEO_LOC': '0',
    'SAT_CART_SUBSTITUTIONS': '1',
    'SAT_OD_SURVEY': '0',
    'sxp-rl-SAT_REORDER_V3-c': 'r|1|20',
    'sxp-rl-SAT_GEO_LOC-c': 'r|1|50',
    'SAT_OPA_CART': '0',
    'SAT_CHAT': '1',
    'sxp-rl-SAT_CART_SUBSTITUTIONS-c': 'r|1|95',
    'AUTOSELECTCLUB': '1',
    'astract': 'ca-0cd1919f-890a-4d48-8ddc-ad108a0badda',
    'AMCVS_B98A1CFE53309C340A490D45%40AdobeOrg': '1',
    'pxcts': '82aea76b-cead-11ed-933f-6e584d42746d',
    '_pxvid': '82ae9474-cead-11ed-933f-6e584d42746d',
    's_ecid': 'MCMID%7C76942460959192918960138354129354148652',
    's_cc': 'true',
    '__pxvid': '82d48f37-cead-11ed-950f-0242ac120002',
    '_gcl_aw': 'GCL.1680148016.Cj0KCQjww4-hBhCtARIsAC9gR3Z9fCJejFyTH_RNhGMDxqX4bjdAmvTuQ4GnENPiEq2LThP9-hj4NucaAps7EALw_wcB',
    '_gcl_au': '1.1.229965859.1680148016',
    '_mibhv': 'anon-1680148018649-8274028012_4591',
    'rmStore': 'dmid:8096',
    '_fbp': 'fb.1.1680148019306.752881107',
    '_derived_epik': 'dj0yJnU9bkpvTkJoTmh6REdVZmFQN3ZQbHlhR3VER1E1NTJiTmImbj1LekYwZTRHMkxWc0V6Rl94bkh5X2NBJm09NyZ0PUFBQUFBR1FvWVA4JnJtPTEmcnQ9QUFBQUFHTUJiLWsmc3A9Mg',
    'SSRT1': 'HmcoZAADAA',
    'TS01bc32b7': '01538efd7cc85cd5ef6a3c549b4fb2a56e026a661ab84f741d991998583395b4d1fd20cb5499d3a8882a6c02dbb266fa9d073eeda6',
    'TS4fc56a0b027': '0800b316f6ab2000e179a8ec3466610e09e482fd5cc33de791a141b44e8c0ede7d3834025420e6f208ea97f560113000e67f5859c9da27bece0c74462a24056de51d7df52d25bfff9fc968d1b3eb1d4a75ff2230cdc4d695fdaa13555959b120',
    '_pxff_idp_c': '1,s',
    '_pxde': '1cb85e0c91b9733132ef4752e593939f0e52364a2d665c94bbd81bbf5c787d85:eyJ0aW1lc3RhbXAiOjE2ODAzNjk0NDQ0OTd9',
    'seqnum': '18',
    'akavpau_P1_Sitewide': '1680370047~id=d8f3debb93dbb558cb931959cf38eb24',
    'xptwj': 'js:1736cce20e8288f0b204:Ln3357xq6HFPI4b42gsoHRyfnRALLqjSGUJeYRB3bZ7c5tx5HLFairoShJPXzctQ/3YWLFxuLBp4i8li0Zy1T8Xk/LLk8ZOfjFbI2AGGfzkQs/51+YCY//pGNbqAvPrw1bzRxU5RCqAt',
    'bm_sv': '23966D1C5ADF848325DC7FD877B0EF26~~1',
    'TS4c030c5e027': '08cb8c7367ab2000aef2e5772c92a49fa9b4977d4fccf68ae765bb58261d3b42f40293a02ced056c08a48f2b11113000e7510f2da9b604288aac2de29d4ce333230d0e1dad1fe37dd827daa18e98d6b90283ad70185ed8a983bada5ec7e8a284',
}

headers = {
    'authority': 'www.samsclub.com',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'en-US,en;q=0.9,hi;q=0.8',
    'cache-control': 'no-cache',
    'content-type': 'application/json',
    # 'cookie': 'SSLB=1; sxp-rl-SAT_OD_SURVEY-rn=44; sxp-rl-SAT_GEO_LOC-rn=69; sxp-rl-SAT_OPA_CART-rn=64; sxp-rl-SAT_CHAT-rn=72; sxp-rl-SAT_CART_SUBSTITUTIONS-rn=64; SCR_PICR=0; az-reg=scus; TS0171ed6c=01538efd7cb3cae2bbdc6593e911d9e38be307f87498b7fa04bd2bece136ff4fddf10764da858c6563e8a93e49cfc04f8a1c4a23b5; sxp-rl-SAT_DISABLE_SYN_PREQUALIFY-rn=4; vtc=c1iSjC5gAV2WXfRUHiKcbI; sxp-rl-SAT_REORDER_V3-rn=67; sxp-rl-SCR_SHAPEJS-rn=62; TS01b2183e=01538efd7cb3cae2bbdc6593e911d9e38be307f87498b7fa04bd2bece136ff4fddf10764da858c6563e8a93e49cfc04f8a1c4a23b5; SAT_WPWCNP=1; sxp-rl-SAT_CHAT-c=r|1|100; SCR_SHAPEJS=0; sxp-rl-SCR_SHAPEJS-c=r|1|0; SAT_REORDER_V3=0; sxp-rl-SAT_OD_SURVEY-c=r|1|20; SAT_DISABLE_SYN_PREQUALIFY=0; sxp-rl-SAT_OPA_CART-c=r|3|20; sxp-rl-SAT_DISABLE_SYN_PREQUALIFY-c=r|1|0; SAT_GEO_LOC=0; SAT_CART_SUBSTITUTIONS=1; SAT_OD_SURVEY=0; sxp-rl-SAT_REORDER_V
c43b8efb22%5E01873dba-98df-46c6-ba43-684f118d0d15%5E0%5E66.189.84.166; cto_bundle=6g-2SF9iTDVCMFglMkJVSEhvakpjTk1uWkZsWSUyQjB3SFdIMVpTMEJQVFJ1UzBGVEJyNVpSeTIwbHZTaWxHWnFzN2cwUllQWVBONDB3bDc2NnJFYXk4TzM3UFhlSzh5cSUyRmgxRzElMkJKY3JFa2N5d2h0b2dmYkRqWUM0WjRzUnBaY0pRQXVtZElxOHl1ZEl4UjQxTXJ4VzNtVWxoJTJCeUZ3JTNEJTNE; _uetsid=89a29c50d02e11ed8332138fccf9667c; _uetvid=85c92af0cead11ed8bfcab1ea7b78d87; _derived_epik=dj0yJnU9bkpvTkJoTmh6REdVZmFQN3ZQbHlhR3VER1E1NTJiTmImbj1LekYwZTRHMkxWc0V6Rl94bkh5X2NBJm09NyZ0PUFBQUFBR1FvWVA4JnJtPTEmcnQ9QUFBQUFHTUJiLWsmc3A9Mg; SSRT1=HmcoZAADAA; TS01bc32b7=01538efd7cc85cd5ef6a3c549b4fb2a56e026a661ab84f741d991998583395b4d1fd20cb5499d3a8882a6c02dbb266fa9d073eeda6; TS4fc56a0b027=0800b316f6ab2000e179a8ec3466610e09e482fd5cc33de791a141b44e8c0ede7d3834025420e6f208ea97f560113000e67f5859c9da27bece0c74462a24056de51d7df52d25bfff9fc968d1b3eb1d4a75ff2230cdc4d695fdaa13555959b120; _pxff_idp_c=1,s; _pxde=1cb85e0c91b9733132ef4752e593939f0e52364a2d665c94bbd81bbf5c787d85:eyJ0aW1lc3RhbXAiOjE2ODAzNjk0NDQ0OTd9; seqnum=18; akavpau_P1_Sitewide=1680370047~id=d8f3debb93dbb558cb931959cf38eb24; xptwj=js:1736cce20e8288f0b204:Ln3357xq6HFPI4b42gsoHRyfnRALLqjSGUJeYRB3bZ7c5tx5HLFairoShJPXzctQ/3YWLFxuLBp4i8li0Zy1T8Xk/LLk8ZOfjFbI2AGGfzkQs/51+YCY//pGNbqAvPrw1bzRxU5RCqAt; bm_sv=23966D1C5ADF848325DC7FD877B0EF26~~1; TS4c030c5e027=08cb8c7367ab2000aef2e5772c92a49fa9b4977d4fccf68ae765bb58261d3b42f40293a02ced056c08a48f2b11113000e7510f2da9b604288aac2de29d4ce333230d0e1dad1fe37dd827daa18e98d6b90283ad70185ed8a983bada5ec7e8a284',
    'dnt': '1',
    'origin': 'https://www.samsclub.com',
    'pragma': 'no-cache',
    'referer': 'https://www.samsclub.com/p/quilted-northern-ultra-soft-strong-toilet-paper-32-rolls-271-sheets/prod23132701?xid=hpg_carousel_rich-relevance.rr0_2',
    'sec-ch-ua': '"Google Chrome";v="111", "Not(A:Brand";v="8", "Chromium";v="111"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/111.0.0.0 Safari/537.36',
    'withdeliveryoffer': 'true',
}

json_data = {
    'productIds': product_ids
}

response = requests.post(
    'https://www.samsclub.com/api/node/vivaldi/browse/v2/products',
    cookies=cookies,
    headers=headers,
    json=json_data,
)

# print(response.text)
# pyperclip.copy(response.text)
product_id_obtained=[]

json_output=json.loads(response.text)
formatted_output=json.dumps(json_output, indent = 4)


# text_file = open("sample.txt", "w")
# n = text_file.write('Welcome to pythonexamples.org')
# text_file.close()
with open('D:/data.json', 'w') as outfile:
    outfile.write(formatted_output)
    outfile.close()

# Check if anything has failed
for product in json_output['payload']['products']:
        product_id_obtained.append(product['productId'])

print("Failed id : "+str(list(set(product_ids)-set(product_id_obtained))))
# Out:
# Failed id : []
